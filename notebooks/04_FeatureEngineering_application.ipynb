# %%
import pandas as pd
import numpy as np
import seaborn as sns

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
pd.set_option('display.max_colwidth', None)

# %%
df0 = pd.read_csv(r'C:\Users\meet.gajera\OneDrive\Desktop\hcdr__\Data\cleaned\application_cleaned.csv')

# %%
df0.head()
# Out:
#    SK_ID_CURR  TARGET CODE_GENDER  DAYS_BIRTH  CNT_CHILDREN  CNT_FAM_MEMBERS  \
# 0      100002       1           M       -9461             0              1.0
# 1      100003       0           F      -16765             0              2.0
# 2      100004       0           M      -19046             0              1.0
# 3      100006       0           F      -19005             0              2.0
# 4      100007       0           M      -19932             0              1.0
#
#   NAME_CONTRACT_TYPE  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0         Cash loans          202500.0    406597.5      24700.5
# 1         Cash loans          270000.0   1293502.5      35698.5
# 2    Revolving loans           67500.0    135000.0       6750.0
# 3         Cash loans          135000.0    312682.5      29686.5
# 4         Cash loans          121500.0    513000.0      21865.5
#
#    AMT_GOODS_PRICE NAME_INCOME_TYPE OCCUPATION_TYPE  OCCUPATION_TYPE_MISSING  \
# 0         351000.0          Working        Laborers                        0
# 1        1129500.0    State servant      Core staff                        0
# 2         135000.0          Working        Laborers                        0
# 3         297000.0          Working        Laborers                        0
# 4         513000.0          Working      Core staff                        0
#
#         ORGANIZATION_TYPE  DAYS_EMPLOYED            NAME_EDUCATION_TYPE  \
# 0  Business Entity Type 3           -637  Secondary / secondary special
# 1                  School          -1188               Higher education
# 2              Government           -225  Secondary / secondary special
# 3  Business Entity Type 3          -3039  Secondary / secondary special
# 4                Religion          -3038  Secondary / secondary special
#
#      NAME_FAMILY_STATUS FLAG_OWN_CAR FLAG_OWN_REALTY  NAME_HOUSING_TYPE  \
# 0  Single / not married            N               Y  House / apartment
# 1               Married            N               N  House / apartment
# 2  Single / not married            Y               Y  House / apartment
# 3        Civil marriage            N               Y  House / apartment
# 4  Single / not married            N               Y  House / apartment
#
#    DAYS_LAST_PHONE_CHANGE  FLAG_EMAIL  FLAG_WORK_PHONE
# 0                 -1134.0           0                0
# 1                  -828.0           0                0
# 2                  -815.0           0                1
# 3                  -617.0           0                0
# 4                 -1106.0           0                0

# %%
df = df0.copy()

# %%
df.shape
# Out:
# (307511, 24)

# %%
df['AGE'] = (-df['DAYS_BIRTH'] / 365).astype(int)

df['YEARS_EMPLOYED'] = round(abs(df['DAYS_EMPLOYED']) / 365, 2)

df['YEARS_CURRENT_PHONE'] = round(abs(df['DAYS_LAST_PHONE_CHANGE']) / 365, 2)

# %%
df.drop(
    columns=[
        'DAYS_BIRTH',
        'DAYS_EMPLOYED',
        'DAYS_LAST_PHONE_CHANGE'
    ],
    inplace=True
)

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET CODE_GENDER  CNT_CHILDREN  CNT_FAM_MEMBERS  \
# 0      100002       1           M             0              1.0
# 1      100003       0           F             0              2.0
# 2      100004       0           M             0              1.0
# 3      100006       0           F             0              2.0
# 4      100007       0           M             0              1.0
#
#   NAME_CONTRACT_TYPE  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0         Cash loans          202500.0    406597.5      24700.5
# 1         Cash loans          270000.0   1293502.5      35698.5
# 2    Revolving loans           67500.0    135000.0       6750.0
# 3         Cash loans          135000.0    312682.5      29686.5
# 4         Cash loans          121500.0    513000.0      21865.5
#
#    AMT_GOODS_PRICE NAME_INCOME_TYPE OCCUPATION_TYPE  OCCUPATION_TYPE_MISSING  \
# 0         351000.0          Working        Laborers                        0
# 1        1129500.0    State servant      Core staff                        0
# 2         135000.0          Working        Laborers                        0
# 3         297000.0          Working        Laborers                        0
# 4         513000.0          Working      Core staff                        0
#
#         ORGANIZATION_TYPE            NAME_EDUCATION_TYPE  \
# 0  Business Entity Type 3  Secondary / secondary special
# 1                  School               Higher education
# 2              Government  Secondary / secondary special
# 3  Business Entity Type 3  Secondary / secondary special
# 4                Religion  Secondary / secondary special
#
#      NAME_FAMILY_STATUS FLAG_OWN_CAR FLAG_OWN_REALTY  NAME_HOUSING_TYPE  \
# 0  Single / not married            N               Y  House / apartment
# 1               Married            N               N  House / apartment
# 2  Single / not married            Y               Y  House / apartment
# 3        Civil marriage            N               Y  House / apartment
# 4  Single / not married            N               Y  House / apartment
#
#    FLAG_EMAIL  FLAG_WORK_PHONE  AGE  YEARS_EMPLOYED  YEARS_CURRENT_PHONE
# 0           0                0   25            1.75                 3.11
# 1           0                0   45            3.25                 2.27
# 2           0                1   52            0.62                 2.23
# 3           0                0   52            8.33                 1.69
# 4           0                0   54            8.32                 3.03

# %%
org_mapping = {
    #  Banking & Finance
    'Bank': 'Banking & Finance',
    'Insurance': 'Banking & Finance',

    #  Government & Public Sector
    'Government': 'Government',
    'Police': 'Government',
    'Military': 'Government',
    'Security Ministries': 'Government',
    'Emergency': 'Government',
    'Postal': 'Government',

    #  Education
    'School': 'Education',
    'University': 'Education',
    'Kindergarten': 'Education',

    #  Healthcare
    'Medicine': 'Healthcare',

    #  IT & Telecom
    'IT': 'IT & Telecom',
    'Telecom': 'IT & Telecom',
    'High skill tech staff': 'IT & Telecom',

    #  Construction & Real Estate
    'Construction': 'Construction',
    'Housing': 'Construction',
    'Realtor': 'Construction',

    #  Hospitality
    'Restaurant': 'Hospitality',
    'Hotel': 'Hospitality',

    #  Transport & Logistics
    'Transport: type 1': 'Transport',
    'Transport: type 2': 'Transport',
    'Transport: type 3': 'Transport',
    'Transport: type 4': 'Transport',

    #  Manufacturing & Industry
    'Industry: type 1': 'Manufacturing',
    'Industry: type 2': 'Manufacturing',
    'Industry: type 3': 'Manufacturing',
    'Industry: type 4': 'Manufacturing',
    'Industry: type 5': 'Manufacturing',
    'Industry: type 6': 'Manufacturing',
    'Industry: type 7': 'Manufacturing',
    'Industry: type 8': 'Manufacturing',
    'Industry: type 9': 'Manufacturing',
    'Industry: type 10': 'Manufacturing',
    'Industry: type 11': 'Manufacturing',
    'Industry: type 12': 'Manufacturing',
    'Industry: type 13': 'Manufacturing',
    'Electricity': 'Manufacturing',

    # Business & Corporate
    'Business Entity Type 1': 'Business & Corporate',
    'Business Entity Type 2': 'Business & Corporate',
    'Business Entity Type 3': 'Business & Corporate',
    'Advertising': 'Business & Corporate',
    'Legal Services': 'Business & Corporate',
    'Services': 'Business & Corporate',

    # Trade & Self-employed
    'Trade: type 1': 'Trade & Self-employed',
    'Trade: type 2': 'Trade & Self-employed',
    'Trade: type 3': 'Trade & Self-employed',
    'Trade: type 4': 'Trade & Self-employed',
    'Trade: type 5': 'Trade & Self-employed',
    'Trade: type 6': 'Trade & Self-employed',
    'Trade: type 7': 'Trade & Self-employed',
    'Self-employed': 'Trade & Self-employed',

    #  Other
    'Agriculture': 'Other',
    'Cleaning': 'Other',
    'Culture': 'Other',
    'Mobile': 'Other',
    'Other': 'Other',
    'Religion': 'Other',
    'Security': 'Other',
    'XNA': 'Other'
}

df['ORG_GROUP'] = (
    df['ORGANIZATION_TYPE']
      .map(org_mapping)
      .fillna('Other')
)

df.drop(columns=['ORGANIZATION_TYPE'], inplace=True)

# %%
df['CRDIT_INCOME_RATIO'] = round(df['AMT_CREDIT']/df['AMT_INCOME_TOTAL'], 4)

# %%
df['ANNUITY_INCOME_RATIO'] = round(df['AMT_ANNUITY']/df['AMT_INCOME_TOTAL'], 4)

# %%
df['CREDIT_ANNUITY_RATIO'] = round(df['AMT_CREDIT']/df['AMT_ANNUITY'], 4)

# %%
df['GOODS_CREDIT_RATIO'] = round(df['AMT_GOODS_PRICE']/df['AMT_CREDIT'], 4)

# %%
df['INCOME_PER_FAM_MEMBER'] = round(df['AMT_INCOME_TOTAL']/df['CNT_FAM_MEMBERS'], 4)

# %%
df['EMPLOYMENT_AGE_RATIO'] = round(df['YEARS_EMPLOYED']/df['AGE'], 4)

# %%
df['NAME_FAMILY_STATUS'].value_counts()
# Out:
# NAME_FAMILY_STATUS
# Married                 196432
# Single / not married     45444
# Civil marriage           29775
# Separated                19770
# Widow                    16088
# Unknown                      2
# Name: count, dtype: int64

# %%
df['IS_SINGLE_PARENT'] = (
                          (df['CNT_CHILDREN']>0) 
                          & 
                          (df['NAME_FAMILY_STATUS'].isin(['Married','Civil marriage']))
                          ).astype(int)

# %%
df['IS_SINGLE_PARENT'].value_counts()
# Out:
# IS_SINGLE_PARENT
# 0    228826
# 1     78685
# Name: count, dtype: int64

# %%
df['HAS_DEPENDENTS'] = (df['CNT_CHILDREN'] > 0).astype(int)

# %%
df['HAS_DEPENDENTS'].value_counts()
# Out:
# HAS_DEPENDENTS
# 0    215371
# 1     92140
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'CODE_GENDER', 'CNT_CHILDREN',
#        'CNT_FAM_MEMBERS', 'NAME_CONTRACT_TYPE', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_INCOME_TYPE',
#        'OCCUPATION_TYPE', 'OCCUPATION_TYPE_MISSING', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY',
#        'NAME_HOUSING_TYPE', 'FLAG_EMAIL', 'FLAG_WORK_PHONE', 'AGE',
#        'YEARS_EMPLOYED', 'YEARS_CURRENT_PHONE', 'ORG_GROUP',
#        'CRDIT_INCOME_RATIO', 'ANNUITY_INCOME_RATIO', 'CREDIT_ANNUITY_RATIO',
#        'GOODS_CREDIT_RATIO', 'INCOME_PER_FAM_MEMBER', 'EMPLOYMENT_AGE_RATIO',
#        'IS_SINGLE_PARENT', 'HAS_DEPENDENTS'],
#       dtype='object')

# %%
df.shape
# Out:
# (307511, 32)

# %%
df.sample(7)
# Out:
#         SK_ID_CURR  TARGET CODE_GENDER  CNT_CHILDREN  CNT_FAM_MEMBERS  \
# 246993      385812       0           F             0              1.0
# 17459       120361       0           M             0              1.0
# 274837      418522       0           F             0              1.0
# 277895      421952       0           F             0              2.0
# 177371      305549       1           M             1              3.0
# 37315       143228       0           F             0              2.0
# 272314      415704       0           F             0              1.0
#
#        NAME_CONTRACT_TYPE  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 246993         Cash loans           54000.0     52128.0       5472.0
# 17459          Cash loans          148500.0    225000.0      11488.5
# 274837         Cash loans          112500.0    278613.0      15993.0
# 277895         Cash loans          315000.0    819792.0      44604.0
# 177371         Cash loans          270000.0    376078.5      25263.0
# 37315     Revolving loans           85500.0    202500.0      10125.0
# 272314         Cash loans          112500.0    354276.0      28120.5
#
#         AMT_GOODS_PRICE      NAME_INCOME_TYPE OCCUPATION_TYPE  \
# 246993          45000.0             Pensioner         Unknown
# 17459          225000.0               Working      Core staff
# 274837         252000.0               Working  Medicine staff
# 277895         720000.0         State servant  Medicine staff
# 177371         310500.0               Working         Drivers
# 37315          202500.0         State servant      Core staff
# 272314         292500.0  Commercial associate        Laborers
#
#         OCCUPATION_TYPE_MISSING            NAME_EDUCATION_TYPE  \
# 246993                        1  Secondary / secondary special
# 17459                         0  Secondary / secondary special
# 274837                        0  Secondary / secondary special
# 277895                        0  Secondary / secondary special
# 177371                        0  Secondary / secondary special
# 37315                         0  Secondary / secondary special
# 272314                        0  Secondary / secondary special
#
#           NAME_FAMILY_STATUS FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 246993  Single / not married            N               Y
# 17459   Single / not married            Y               N
# 274837  Single / not married            Y               Y
# 277895               Married            N               Y
# 177371               Married            Y               Y
# 37315                Married            N               N
# 272314  Single / not married            N               Y
#
#           NAME_HOUSING_TYPE  FLAG_EMAIL  FLAG_WORK_PHONE  AGE  YEARS_EMPLOYED  \
# 246993    House / apartment           0                0   62         1000.67
# 17459     House / apartment           0                1   23            2.05
# 274837    House / apartment           0                0   35            3.45
# 277895    House / apartment           0                0   53            6.11
# 177371    House / apartment           0                1   46            0.65
# 37315   Municipal apartment           0                1   28            2.19
# 272314    House / apartment           0                0   24            0.90
#
#         YEARS_CURRENT_PHONE             ORG_GROUP  CRDIT_INCOME_RATIO  \
# 246993                 5.68                 Other              0.9653
# 17459                  3.34             Education              1.5152
# 274837                 5.58  Business & Corporate              2.4766
# 277895                 0.70             Education              2.6025
# 177371                 4.06  Business & Corporate              1.3929
# 37315                  0.46             Education              2.3684
# 272314                 0.00  Business & Corporate              3.1491
#
#         ANNUITY_INCOME_RATIO  CREDIT_ANNUITY_RATIO  GOODS_CREDIT_RATIO  \
# 246993                0.1013                9.5263              0.8633
# 17459                 0.0774               19.5848              1.0000
# 274837                0.1422               17.4209              0.9045
# 277895                0.1416               18.3793              0.8783
# 177371                0.0936               14.8865              0.8256
# 37315                 0.1184               20.0000              1.0000
# 272314                0.2500               12.5985              0.8256
#
#         INCOME_PER_FAM_MEMBER  EMPLOYMENT_AGE_RATIO  IS_SINGLE_PARENT  \
# 246993                54000.0               16.1398                 0
# 17459                148500.0                0.0891                 0
# 274837               112500.0                0.0986                 0
# 277895               157500.0                0.1153                 0
# 177371                90000.0                0.0141                 1
# 37315                 42750.0                0.0782                 0
# 272314               112500.0                0.0375                 0
#
#         HAS_DEPENDENTS
# 246993               0
# 17459                0
# 274837               0
# 277895               0
# 177371               1
# 37315                0
# 272314               0

# %%
# saving featured csv

df.to_csv(r"C:\Users\meet.gajera\OneDrive\Desktop\hcdr__\Data\featured\application_featured.csv", index=False)
